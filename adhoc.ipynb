# %%
from basketball_reference_web_scraper import client

# %%
client.search(term="Jalen")
# Out:
# {'players': [{'name': 'Jalen Rose',
#    'identifier': 'roseja01',
#    'leagues': set()},
#   {'name': 'Jalen Brunson', 'identifier': 'brunsja01', 'leagues': set()},
#   {'name': 'Jalen Green', 'identifier': 'greenja05', 'leagues': set()},
#   {'name': 'Jalen Williams', 'identifier': 'willija06', 'leagues': set()},
#   {'name': 'Jalen Suggs', 'identifier': 'suggsja01', 'leagues': set()},
#   {'name': 'Jalen Smith', 'identifier': 'smithja04', 'leagues': set()},
#   {'name': 'Jalen Johnson', 'identifier': 'johnsja05', 'leagues': set()},
#   {'name': 'Jalen Duren', 'identifier': 'durenja01', 'leagues': set()},
#   {'name': 'Jalen McDaniels', 'identifier': 'mcdanja01', 'leagues': set()},
#   {'name': 'Jalen Wilson', 'identifier': 'wilsoja03', 'leagues': set()},
#   {'name': 'Jalen Jones', 'identifier': 'jonesja04', 'leagues': set()},
#   {'name': 'Jalen Harris', 'identifier': 'harrija01', 'leagues': set()},
#   {'name': 'Jalen Pickett', 'identifier': 'pickeja02', 'leagues': set()},
# ...
