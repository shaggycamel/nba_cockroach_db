# %% [markdown]
# # Future instruction
# When it comes to updating database objects at the start of the season, I need to ensure each df fits with its corresponding db table.
# In terms of "fit":
#     <br>&emsp;If replace, ensure the new object contains all data and none is lost
#     <br>&emsp;If append, ensure the df to be unioned is correct

# %%
import pandas as pd; pd.set_option('display.max_columns', 500)
from sqlalchemy.dialects.postgresql.base import PGDialect; PGDialect._get_server_version_info = lambda *args: (9, 2)
from dataHub import dataHub
dh = dataHub()

db_con = dh.db_connect('cockroach')
fty_con = dh.fty_api_con()

# %%
pd.read_sql_query("SELECT table_name FROM util.update_log WHERE successful_run = False", db_con)
# Out:
# ---------------------------------------------------------------------------
# InvalidParameterValue                     Traceback (most recent call last)
# File /opt/homebrew/lib/python3.11/site-packages/sqlalchemy/engine/base.py:1965, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1964     if not evt_handled:
# -> 1965         self.dialect.do_execute(
#    1966             cursor, str_statement, effective_parameters, context
#    1967         )
#    1969 if self._has_events or self.engine._has_events:
#
# File /opt/homebrew/lib/python3.11/site-packages/sqlalchemy/engine/default.py:921, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     920 def do_execute(self, cursor, statement, parameters, context=None):
# --> 921     cursor.execute(statement, parameters)
#
# InvalidParameterValue: unsupported comparison operator: <string> = <bool>
#
#
# The above exception was the direct cause of the following exception:
#
# DataError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 pd.read_sql_query("SELECT table_name FROM util.update_log WHERE successful_run = False", db_con)
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/io/sql.py:469, in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize, dtype, dtype_backend)
#     466     dtype_backend = "numpy"  # type: ignore[assignment]
#     468 with pandasSQL_builder(con) as pandas_sql:
# --> 469     return pandas_sql.read_query(
#     470         sql,
#     471         index_col=index_col,
#     472         params=params,
#     473         coerce_float=coerce_float,
#     474         parse_dates=parse_dates,
#     475         chunksize=chunksize,
#     476         dtype=dtype,
#     477         dtype_backend=dtype_backend,
#     478     )
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/io/sql.py:1738, in SQLDatabase.read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype, dtype_backend)
#    1681 def read_query(
#    1682     self,
#    1683     sql: str,
#    (...)
#    1690     dtype_backend: DtypeBackend | Literal["numpy"] = "numpy",
#    1691 ) -> DataFrame | Iterator[DataFrame]:
#    1692     """
#    1693     Read SQL query into a DataFrame.
#    1694
#    (...)
#    1736
#    1737     """
# -> 1738     result = self.execute(sql, params)
#    1739     columns = result.keys()
#    1741     if chunksize is not None:
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/io/sql.py:1562, in SQLDatabase.execute(self, sql, params)
#    1560 args = [] if params is None else [params]
#    1561 if isinstance(sql, str):
# -> 1562     return self.con.exec_driver_sql(sql, *args)
#    1563 return self.con.execute(sql, *args)
#
# File /opt/homebrew/lib/python3.11/site-packages/sqlalchemy/engine/base.py:1774, in Connection.exec_driver_sql(self, statement, parameters, execution_options)
#    1769 execution_options = self._execution_options.merge_with(
#    1770     execution_options
#    1771 )
#    1773 dialect = self.dialect
# -> 1774 ret = self._execute_context(
#    1775     dialect,
#    1776     dialect.execution_ctx_cls._init_statement,
#    1777     statement,
#    1778     None,
#    1779     execution_options,
#    1780     statement,
#    1781     distilled_parameters,
#    1782 )
#    1784 return ret
#
# File /opt/homebrew/lib/python3.11/site-packages/sqlalchemy/engine/base.py:1844, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1839     return self._exec_insertmany_context(
#    1840         dialect,
#    1841         context,
#    1842     )
#    1843 else:
# -> 1844     return self._exec_single_context(
#    1845         dialect, context, statement, parameters
#    1846     )
#
# File /opt/homebrew/lib/python3.11/site-packages/sqlalchemy/engine/base.py:1984, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1981     result = context._setup_result_proxy()
#    1983 except BaseException as e:
# -> 1984     self._handle_dbapi_exception(
#    1985         e, str_statement, effective_parameters, cursor, context
#    1986     )
#    1988 return result
#
# File /opt/homebrew/lib/python3.11/site-packages/sqlalchemy/engine/base.py:2339, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context, is_sub_exec)
#    2337 elif should_wrap:
#    2338     assert sqlalchemy_exception is not None
# -> 2339     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2340 else:
#    2341     assert exc_info[1] is not None
#
# File /opt/homebrew/lib/python3.11/site-packages/sqlalchemy/engine/base.py:1965, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1963                 break
#    1964     if not evt_handled:
# -> 1965         self.dialect.do_execute(
#    1966             cursor, str_statement, effective_parameters, context
#    1967         )
#    1969 if self._has_events or self.engine._has_events:
#    1970     self.dispatch.after_cursor_execute(
#    1971         self,
#    1972         cursor,
#    (...)
#    1976         context.executemany,
#    1977     )
#
# File /opt/homebrew/lib/python3.11/site-packages/sqlalchemy/engine/default.py:921, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     920 def do_execute(self, cursor, statement, parameters, context=None):
# --> 921     cursor.execute(statement, parameters)
#
# DataError: (psycopg2.errors.InvalidParameterValue) unsupported comparison operator: <string> = <bool>
#
# [SQL: SELECT table_name FROM util.update_log WHERE successful_run = False]
# (Background on this error at: https://sqlalche.me/e/20/9h9h)

# %% [markdown]
# # Player Season Stats
# Updated at the start of the season and can continue to be updated daily or weekly. This depends on how frequently the season_stat object is refreshed on the nba_api

# %%
player_season_stats = dh.get_player_season_stats(db_con)
player_season_stats.head()
# Out:
# --------------------- player season stats
# player: 0 / 535
# player: 50 / 535
# player: 100 / 535
# player: 150 / 535
# player: 200 / 535
# player: 250 / 535
# player: 300 / 535
# player: 350 / 535
# player: 400 / 535
# player: 450 / 535
# player: 500 / 535
# player: 534 / 535
# player_season_stats has been updated
#   season_id     team_id team_abbreviation player_id  player_age  gp  gs  \
# 0   2003-04  1610612739               CLE      2544        19.0  79  79
# 1   2003-04  1610612748               MIA      2617        24.0  75  24
# 2   2004-05  1610612739               CLE      2544        20.0  80  80
# 3   2004-05  1610612748               MIA      2617        25.0  80  80
# 4   2004-05  1610612755               PHI      2738        21.0  82  82
#
#       min  fgm   fga  fg_pct fg3_m fg3_a  fg3_pct  ftm  fta  ft_pct   pts  \
# 0  3120.0  622  1492   0.417    63   217    0.290  347  460   0.754  1654
# 1  1798.0  205   447   0.459     0     3    0.000  140  183   0.765   550
# 2  3388.0  795  1684   0.472   108   308    0.351  477  636   0.750  2175
# 3  2675.0  346   641   0.540     0     4    0.000  178  225   0.791   870
# 4  2688.0  269   546   0.493    47   142    0.331  156  210   0.743   741
#
#     pf oreb dreb  reb  ast  stl blk  tov
# 0  149   99  333  432  465  130  58  273
# 1  197  189  284  473   51   33  24   74
# 2  146  111  477  588  577  177  52  262
# 3  260  239  487  726  108   63  41  113
# 4  204   89  375  464  246  138  48  139

# %% [markdown]
# # Player Info
# Updated once at the start of each season

# %%
player_info = dh.get_player_info(db_con)
player_info.head()
# Out:
# --------------------- player_info
# player: 0 / 535
# player: 50 / 535
# player: 100 / 535

# %% [markdown]
# # Player Game Log
# Updated at the start of the season and daily for the rest of the season. Remember to control for season type list ['Pre Season', 'Regular Season', etc....]

# %%
player_game_log = dh.get_player_game_log(db_con)
player_game_log.head()
# Out:
# --------------------- player_game_log
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 player_game_log = dh.get_player_game_log(db_con)
#       2 player_game_log.head()
#
# File ~/git/nba_cockroach_db/dataHub.py:125, in dataHub.get_player_game_log(self, db_connection)
#     123 for player in active_players_list:
#     124     for season_type in season_types:
# --> 125         player_game_log = playergamelog.PlayerGameLog(
#     126             player_id=str(player),
#     127             date_from_nullable=date_from,
#     128             date_to_nullable=date_to,
#     129             season_type_all_star=season_type
#     130         )
#     131         player_game_log = player_game_log.data_sets[0].get_data_frame()
#     132         player_game_log['season_type'] = season_type
#
# File /opt/homebrew/lib/python3.11/site-packages/nba_api/stats/endpoints/playergamelog.py:40, in PlayerGameLog.__init__(self, player_id, season, season_type_all_star, date_from_nullable, date_to_nullable, league_id_nullable, proxy, headers, timeout, get_request)
#      31 self.parameters = {
#      32         'PlayerID': player_id,
#      33         'Season': season,
#    (...)
#      37         'LeagueID': league_id_nullable
#      38 }
#      39 if get_request:
# ---> 40     self.get_request()
#
# File /opt/homebrew/lib/python3.11/site-packages/nba_api/stats/endpoints/playergamelog.py:50, in PlayerGameLog.get_request(self)
#      42 def get_request(self):
#      43     self.nba_response = NBAStatsHTTP().send_api_request(
#      44         endpoint=self.endpoint,
#      45         parameters=self.parameters,
#    (...)
#      48         timeout=self.timeout,
#      49     )
# ---> 50     self.load_response()
#
# File /opt/homebrew/lib/python3.11/site-packages/nba_api/stats/endpoints/playergamelog.py:53, in PlayerGameLog.load_response(self)
#      52 def load_response(self):
# ---> 53     data_sets = self.nba_response.get_data_sets()
#      54     self.data_sets = [Endpoint.DataSet(data=data_set) for data_set_name, data_set in data_sets.items()]
#      55     self.player_game_log = Endpoint.DataSet(data=data_sets['PlayerGameLog'])
#
# File /opt/homebrew/lib/python3.11/site-packages/nba_api/stats/library/http.py:83, in NBAStatsResponse.get_data_sets(self)
#      82 def get_data_sets(self):
# ---> 83     raw_dict = self.get_dict()
#      84     if 'resultSets' in raw_dict:
#      85         results = raw_dict['resultSets']
#
# File /opt/homebrew/lib/python3.11/site-packages/nba_api/library/http.py:41, in NBAResponse.get_dict(self)
#      40 def get_dict(self):
# ---> 41     return json.loads(self._response)
#
# File /opt/homebrew/Cellar/python@3.11/3.11.4_1/Frameworks/Python.framework/Versions/3.11/lib/python3.11/json/__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#     348     cls = JSONDecoder
#
# File /opt/homebrew/Cellar/python@3.11/3.11.4_1/Frameworks/Python.framework/Versions/3.11/lib/python3.11/json/decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     332 def decode(self, s, _w=WHITESPACE.match):
#     333     """Return the Python representation of ``s`` (a ``str`` instance
#     334     containing a JSON document).
#     335
#     336     """
# --> 337     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338     end = _w(s, end).end()
#     339     if end != len(s):
#
# File /opt/homebrew/Cellar/python@3.11/3.11.4_1/Frameworks/Python.framework/Versions/3.11/lib/python3.11/json/decoder.py:355, in JSONDecoder.raw_decode(self, s, idx)
#     353     obj, end = self.scan_once(s, idx)
#     354 except StopIteration as err:
# --> 355     raise JSONDecodeError("Expecting value", s, err.value) from None
#     356 return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %% [markdown]
# # Game Schedule
# Use update_historical_game_schedule() to update records from last season. Use get_next_game_schedule() to obtain schedule for upcoming season. Run both functions at the start of each season

# %%
hist_game_schedule = dh.update_historical_game_schedule(db_con)
hist_game_schedule.head()

# %%
next_game_schedule = dh.get_next_game_schedule(db_con)
next_game_schedule.head()

# %% [markdown]
# # Team Roster
# Updated at the start of the season and after trade deadline

# %%
team_roster = dh.get_team_roster(db_con)
team_roster.head()

# %% [markdown]
# # Fantasy data instruction
# Do this part later

# %% [markdown]
# # Free Agents
# Updated daily

# %%
free_agents = dh.fty_get_free_agents(fty_con.free_agents(size=1000), db_con)
free_agents.head()

# %% [markdown]
# # Fantasy Team Rosters
# Updated daily

# %%
fty_con.teams
