# %% [markdown]
# # Future instruction
# When it comes to updating database objects at the start of the season, I need to ensure each df fits with its corresponding db table.
# In terms of "fit":
#     <br>&emsp;If replace, ensure the new object contains all data and none is lost
#     <br>&emsp;If append, ensure the df to be unioned is correct

# %%
import pandas as pd; pd.set_option('display.max_columns', 500)
from dataHub import dataHub
dh = dataHub()

postgre_con = dh.db_connect('postgre')
fty_con = dh.fty_api_con()

# %% [markdown]
# # Player Season Stats
# Updated at the start of the season and can continue to be updated daily or weekly. This depends on how frequently the season_stat object is refreshed on the nba_api

# %%
player_season_stats = dh.get_player_season_stats(postgre_con)
player_season_stats.head()
# Out:
# --------------------- player season stats
# player: 0 / 535
# player: 50 / 535
# player: 100 / 535
# player: 150 / 535
# player: 200 / 535
# player: 250 / 535
# player: 300 / 535
# player: 350 / 535
# player: 400 / 535
# player: 450 / 535
# player: 500 / 535
# player: 534 / 535
# player_season_stats has been updated
#   season_id     team_id team_abbreviation player_id  player_age  gp  gs  \
# 0   2003-04  1610612739               CLE      2544        19.0  79  79
# 1   2003-04  1610612748               MIA      2617        24.0  75  24
# 2   2004-05  1610612739               CLE      2544        20.0  80  80
# 3   2004-05  1610612748               MIA      2617        25.0  80  80
# 4   2004-05  1610612755               PHI      2738        21.0  82  82
#
#       min  fgm   fga  fg_pct fg3_m fg3_a  fg3_pct  ftm  fta  ft_pct   pts  \
# 0  3120.0  622  1492   0.417    63   217    0.290  347  460   0.754  1654
# 1  1798.0  205   447   0.459     0     3    0.000  140  183   0.765   550
# 2  3388.0  795  1684   0.472   108   308    0.351  477  636   0.750  2175
# 3  2675.0  346   641   0.540     0     4    0.000  178  225   0.791   870
# 4  2688.0  269   546   0.493    47   142    0.331  156  210   0.743   741
#
#     pf oreb dreb  reb  ast  stl blk  tov
# 0  149   99  333  432  465  130  58  273
# 1  197  189  284  473   51   33  24   74
# 2  146  111  477  588  577  177  52  262
# 3  260  239  487  726  108   63  41  113
# 4  204   89  375  464  246  138  48  139

# %% [markdown]
# # Player Info
# Updated once at the start of each season

# %%
player_info = dh.get_player_info(postgre_con)
player_info.head()
# Out:
# --------------------- player_info
# player: 0 / 535
# player: 50 / 535
# player: 100 / 535
# player: 150 / 535
# player: 200 / 535
# player: 250 / 535
# player: 300 / 535
# player: 350 / 535
# player: 400 / 535
# player: 450 / 535
# player: 500 / 535
# player: 534 / 535
# player_info has been updated
#    person_id first_name last_name display_first_last display_last_comma_first  \
# 0    1630173   Precious   Achiuwa   Precious Achiuwa        Achiuwa, Precious
# 1     203500     Steven     Adams       Steven Adams            Adams, Steven
# 2    1628389        Bam   Adebayo        Bam Adebayo             Adebayo, Bam
# 3    1630534      Ochai    Agbaji       Ochai Agbaji            Agbaji, Ochai
# 4    1630583      Santi    Aldama       Santi Aldama            Aldama, Santi
#
#   display_fi_last       player_slug            birthdate           school  \
# 0      P. Achiuwa  precious-achiuwa  1999-09-19T00:00:00          Memphis
# 1        S. Adams      steven-adams  1993-07-20T00:00:00       Pittsburgh
# 2      B. Adebayo       bam-adebayo  1997-07-18T00:00:00         Kentucky
# 3       O. Agbaji      ochai-agbaji  2000-04-20T00:00:00           Kansas
# 4       S. Aldama      santi-aldama  2001-01-10T00:00:00  Loyola-Maryland
#
#        country        last_affiliation height weight  season_exp jersey  \
# 0      Nigeria         Memphis/Nigeria    6-8    225           3      5
# 1  New Zealand  Pittsburgh/New Zealand   6-11    265          10      4
# 2          USA            Kentucky/USA    6-9    255           6     13
# 3          USA              Kansas/USA    6-5    215           1     30
# 4        Spain   Loyola-Maryland/Spain    7-0    215           2      7
#
#          position rosterstatus games_played_current_season_flag     team_id  \
# 0         Forward       Active                                N  1610612761
# 1          Center       Active                                N  1610612763
# 2  Center-Forward       Active                                N  1610612748
# 3           Guard       Active                                N  1610612762
# 4  Forward-Center       Active                                N  1610612763
#
#    team_name team_abbreviation  team_code team_city        playercode  \
# 0    Raptors               TOR    raptors   Toronto  precious_achiuwa
# 1  Grizzlies               MEM  grizzlies   Memphis      steven_adams
# 2       Heat               MIA       heat     Miami       bam_adebayo
# 3       Jazz               UTA       jazz      Utah      ochai_agbaji
# 4  Grizzlies               MEM  grizzlies   Memphis      santi_aldama
#
#    from_year  to_year dleague_flag nba_flag games_played_flag draft_year  \
# 0       2020     2023            N        Y                 Y       2020
# 1       2013     2023            N        Y                 Y       2013
# 2       2017     2023            N        Y                 Y       2017
# 3       2022     2023            Y        Y                 Y       2022
# 4       2021     2023            Y        Y                 Y       2021
#
#   draft_round draft_number greatest_75_flag
# 0           1           20                N
# 1           1           12                N
# 2           1           14                N
# 3           1           14                N
# 4           1           30                N

# %% [markdown]
# # Player Game Log
# Updated at the start of the season and daily for the rest of the season. Remember to control for season type list ['Pre Season', 'Regular Season', etc....]

# %%
player_game_log = dh.get_player_game_log(postgre_con)
player_game_log.head()
# Out:
# --------------------- player_game_log
# player: 0 / 535
# player: 50 / 535
# player: 100 / 535
# player: 150 / 535
# player: 200 / 535
# player: 250 / 535
# player: 300 / 535
# player: 350 / 535
# player: 400 / 535
# player: 450 / 535
# player: 500 / 535
# player: 534 / 535
# player_game_log has been updated to: 2023-07-23
# Empty DataFrame
# Columns: [year_season, slug_season, season_type, game_date, game_id, matchup, wl, player_id, fgm, fga, fg_pct, fg3_m, fg3_a, fg3_pct, ft_pct, video_available, min, ftm, fta, oreb, dreb, reb, ast, stl, blk, tov, pf, pts, plus_minus]
# Index: []

# %% [markdown]
# # Game Schedule
# Use update_historical_game_schedule() to update records from last season. Use get_next_game_schedule() to obtain schedule for upcoming season. Run both functions at the start of each season

# %%
hist_game_schedule = dh.update_historical_game_schedule(postgre_con)
hist_game_schedule.head()
# Out:
# --------------------- historical_league_game_schedule
# historical_game_schedule has been updated
#   SEASON_ID       TEAM_ID TEAM_ABBREVIATION              TEAM_NAME  \
# 0     22021  1.610613e+09               BKN          Brooklyn Nets
# 1     22021  1.610613e+09               MIL        Milwaukee Bucks
# 2     22021  1.610613e+09               GSW  Golden State Warriors
# 3     22021  1.610613e+09               LAL     Los Angeles Lakers
# 4     22021  1.610613e+09               CHA      Charlotte Hornets
#
#       GAME_ID   GAME_DATE      MATCHUP WL    MIN   FGM    FGA  FG_PCT  FG3M  \
# 0  0022100001  2021-10-19    BKN @ MIL  L  240.0  37.0   84.0   0.440  17.0
# 1  0022100001  2021-10-19  MIL vs. BKN  W  240.0  48.0  105.0   0.457  17.0
# 2  0022100002  2021-10-19    GSW @ LAL  W  240.0  41.0   93.0   0.441  14.0
# 3  0022100002  2021-10-19  LAL vs. GSW  L  240.0  45.0   95.0   0.474  15.0
# 4  0022100003  2021-10-20  CHA vs. IND  W  240.0  46.0  107.0   0.430  13.0
#
#    FG3A  FG3_PCT   FTM   FTA  FT_PCT  OREB  DREB   REB   AST  STL  BLK   TOV  \
# 0  32.0    0.531  13.0  23.0   0.565   5.0  39.0  44.0  19.0  3.0  9.0  13.0
# 1  45.0    0.378  14.0  18.0   0.778  13.0  41.0  54.0  25.0  8.0  9.0   8.0
# 2  39.0    0.359  25.0  30.0   0.833   9.0  41.0  50.0  30.0  9.0  2.0  17.0
# 3  42.0    0.357   9.0  19.0   0.474   5.0  40.0  45.0  21.0  7.0  4.0  18.0
# 4  31.0    0.419  18.0  27.0   0.667  12.0  34.0  46.0  29.0  9.0  5.0   8.0
#
#      PF    PTS  PLUS_MINUS  VIDEO_AVAILABLE     season_type type_season  \
# 0  17.0  104.0       -23.0              1.0  Regular Season         NaN
# 1  19.0  127.0        23.0              1.0  Regular Season         NaN
# 2  18.0  121.0         7.0              1.0  Regular Season         NaN
# 3  25.0  114.0        -7.0              1.0  Regular Season         NaN
# 4  21.0  123.0         1.0              1.0  Regular Season         NaN
#
#   slug_season  game_id game_date slug_matchup slug_team_winner  \
# 0         NaN      NaN       NaN          NaN              NaN
# 1         NaN      NaN       NaN          NaN              NaN
# 2         NaN      NaN       NaN          NaN              NaN
# 3         NaN      NaN       NaN          NaN              NaN
# 4         NaN      NaN       NaN          NaN              NaN
#
#   slug_team_loser  number_game_day
# 0             NaN              NaN
# 1             NaN              NaN
# 2             NaN              NaN
# 3             NaN              NaN
# 4             NaN              NaN

# %%
next_game_schedule = dh.get_next_game_schedule(postgre_con)
next_game_schedule.head()
# Out:
# current_game_schedule has been updated
#   type_season slug_season     game_id  game_date slug_matchup  \
# 0        None     2022-23  0022200547 2023-01-01  MEM vs. SAC
# 1        None     2022-23  0022200548 2023-01-01  MIL vs. WAS
# 2        None     2022-23  0022200549 2023-01-01  DEN vs. BOS
# 3        None     2022-23  0022200550 2023-01-02  NYK vs. PHX
# 4        None     2022-23  0022200551 2023-01-02  CHA vs. LAL
#
#   slug_team_winner slug_team_loser number_game_day
# 0             None            None            None
# 1             None            None            None
# 2             None            None            None
# 3             None            None            None
# 4             None            None            None

# %% [markdown]
# # Team Roster
# Updated at the start of the season and after trade deadline

# %%
team_roster = dh.get_team_roster(postgre_con)
team_roster.head()
# Out:
# --------------------- commonteamroster
# team: 0 / 30
# team: 5 / 30
# team: 10 / 30
# team: 15 / 30
# team: 20 / 30
# team: 25 / 30
# team: 29 / 30
# historical_game_schedule has been updated
#   slug_season season team_slug     team_id  player_id            player  \
# 0     2022-23   2022       ATL  1610612737    1631495  Donovan Williams
# 1     2022-23   2022       ATL  1610612737    1628981    Bruno Fernando
# 2     2022-23   2022       ATL  1610612737    1630552     Jalen Johnson
# 3     2022-23   2022       ATL  1610612737    1630235     Trent Forrest
# 4     2022-23   2022       ATL  1610612737    1628988     Aaron Holiday
#
#   nickname       player_slug   num position height weight    birth_date   age  \
# 0  Donovan  donovan-williams  None        G    6-6    190  SEP 06, 2001  21.0
# 1    Bruno    bruno-fernando     0      F-C   6-10    240  AUG 15, 1998  24.0
# 2    Jalen     jalen-johnson     1        F    6-8    219  DEC 18, 2001  21.0
# 3    Trent     trent-forrest     2        G    6-4    210  JUN 12, 1998  25.0
# 4    Aaron     aaron-holiday     3        G    6-0    185  SEP 30, 1996  26.0
#
#   exp         school                 how_acquired
# 0   R           UNLV                         None
# 1   3       Maryland  Traded from HOU on 02/09/23
# 2   1           Duke       #20 Pick in 2021 Draft
# 3   2  Florida State           Signed on 08/08/22
# 4   4           UCLA                         None

# %% [markdown]
# # Fantasy data instruction
# Do this part later

# %% [markdown]
# # Free Agents
# Updated daily

# %%
free_agents = dh.fty_get_free_agents(fty_con.free_agents(size=1000), postgre_con)
free_agents.head()
# Out:
# free_agents has been updated
#    player_id        player_name player_team player_status player_position
# 0       3468  Russell Westbrook         LAC        ACTIVE              PG
# 1    4395725        Tyler Herro         MIA        ACTIVE              SG
# 2       6440      Tobias Harris         PHL        ACTIVE              SF
# 3       4251        Paul George         LAC           OUT              SF
# 4    3058254     Christian Wood         DAL        ACTIVE               C

# %% [markdown]
# # Fantasy Team Rosters
# Updated daily

# %%
fty_con.teams
# Out:
# [Team(Philly 5 ⭐️ Men),
#  Team(El Barto ),
#  Team(Hawkes Bay Bombers),
#  Team(Ashhurst Beasthunters),
#  Team(Naboo Fred-Ball),
#  Team(Capital city Cantz),
#  Team(Manawatu McGregor ),
#  Team(Taranaki  Thunder)]
