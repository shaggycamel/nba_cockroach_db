# %%
import pandas as pd; pd.set_option('display.max_columns', 500)
from dataHub import dataHub
import snakecase

dh = dataHub()
postgre_con = dh.db_connect('postgre')
cockroach_con = dh.db_connect('cockroach')

# injuries

# %%
col_order = pd.read_sql_query("SELECT column_name FROM util.table_column_order WHERE table_name = 'player_season_stats' ORDER BY column_order", postgre_con)['column_name'].to_list()

# %%
col_order
# Out:
# ['season_id',
#  'team_id',
#  'team_abbreviation',
#  'player_id',
#  'player_age',
#  'gp',
#  'gs',
#  'min',
#  'fgm',
#  'fga',
#  'fg_pct',
#  'fg3_m',
#  'fg3_a',
#  'fg3_pct',
#  'ftm',
#  'fta',
#  'ft_pct',
#  'pts',
#  'pf',
#  'oreb',
#  'dreb',
#  'reb',
#  'ast',
#  'stl',
#  'blk',
#  'tov']
