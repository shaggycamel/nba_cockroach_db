# %% [markdown]
# # Future instruction
# When it comes to updating database objects at the start of the season, I need to ensure each df fits with its corresponding db table.
# In terms of "fit":
#     <br>&emsp;If replace, ensure the new object contains all data and none is lost
#     <br>&emsp;If append, ensure the df to be unioned is correct

# %%
import pandas as pd; pd.set_option('display.max_columns', 500)
from sqlalchemy.dialects.postgresql.base import PGDialect; PGDialect._get_server_version_info = lambda *args: (9, 2)
from dataHub import dataHub

dh = dataHub()
db_con = dh.db_connect('cockroach')
# db_con = dh.db_connect('postgre')
fty_con = dh.fty_con(db_con)

# %% [markdown]
# # Player Season Stats
# Updated at the start of the season and can continue to be updated daily or weekly. This depends on how frequently the season_stat object is refreshed on the nba_api

# %%
# dh.get_player_season_stats(db_con)

# %% [markdown]
# # Player Info
# Updated once at the start of each season

# %%
# dh.get_player_info(db_con)

# %% [markdown]
# # Player Game Log
# Updated at the start of the season and daily for the rest of the season. Remember to control for season type list ['Pre Season', 'Regular Season', etc....]

# %%
# dh.get_player_game_log(db_con)

# %% [markdown]
# # Game Schedule
# Use update_historical_game_schedule() to update records from last season. Use get_next_game_schedule() to obtain schedule for upcoming season. Run both functions at the start of each season

# %%
# dh.update_past_game_schedule(db_con)

# %%
# dh.get_next_game_schedule(db_con)

# %% [markdown]
# # Box Scores

# %%
dh.get_box_score(db_con)
# Out:
# --------------------- nba.player/team_box_score
# nba.player/team_box_score have been updated

# %% [markdown]
# # Team Roster
# Updated at the start of the season and after trade deadline

# %%
# dh.get_team_roster(db_con)

# %% [markdown]
# # Transactions

# %%
dh.get_transactions(db_con)
# Out:
# --------------------- nba.transaction_log
# ---------------------------------------------------------------------------
# PendingRollbackError                      Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 dh.get_transactions(db_con)
#
# File ~/git/nba_cockroach_db/dataHub.py:370, in dataHub.get_transactions(self, db_con)
#     367 def get_transactions(self, db_con):
#     369     print('\n--------------------- nba.transaction_log')
# --> 370     col_order = read_sql("SELECT column_name FROM util.table_column_order WHERE table_name = 'transaction_log' ORDER BY column_order", db_con)['column_name'].to_list()
#     371     date_from = read_sql('SELECT MAX(date) FROM nba.transaction_log', db_con)['max'][0] - timedelta(days=7) # four days leway, unless records are added late
#     373     async def search_transactions(starting_row, transaction_type) -> str:
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/io/sql.py:663, in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize, dtype_backend, dtype)
#     653     return pandas_sql.read_table(
#     654         sql,
#     655         index_col=index_col,
#    (...)
#     660         dtype_backend=dtype_backend,
#     661     )
#     662 else:
# --> 663     return pandas_sql.read_query(
#     664         sql,
#     665         index_col=index_col,
#     666         params=params,
#     667         coerce_float=coerce_float,
#     668         parse_dates=parse_dates,
#     669         chunksize=chunksize,
#     670         dtype_backend=dtype_backend,
#     671         dtype=dtype,
#     672     )
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/io/sql.py:1738, in SQLDatabase.read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype, dtype_backend)
#    1681 def read_query(
#    1682     self,
#    1683     sql: str,
#    (...)
#    1690     dtype_backend: DtypeBackend | Literal["numpy"] = "numpy",
#    1691 ) -> DataFrame | Iterator[DataFrame]:
#    1692     """
#    1693     Read SQL query into a DataFrame.
#    1694
#    (...)
#    1736
#    1737     """
# -> 1738     result = self.execute(sql, params)
#    1739     columns = result.keys()
#    1741     if chunksize is not None:
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/io/sql.py:1562, in SQLDatabase.execute(self, sql, params)
#    1560 args = [] if params is None else [params]
#    1561 if isinstance(sql, str):
# -> 1562     return self.con.exec_driver_sql(sql, *args)
#    1563 return self.con.execute(sql, *args)
#
# File /opt/homebrew/lib/python3.11/site-packages/sqlalchemy/engine/base.py:1774, in Connection.exec_driver_sql(self, statement, parameters, execution_options)
#    1769 execution_options = self._execution_options.merge_with(
#    1770     execution_options
#    1771 )
#    1773 dialect = self.dialect
# -> 1774 ret = self._execute_context(
#    1775     dialect,
#    1776     dialect.execution_ctx_cls._init_statement,
#    1777     statement,
#    1778     None,
#    1779     execution_options,
#    1780     statement,
#    1781     distilled_parameters,
#    1782 )
#    1784 return ret
#
# File /opt/homebrew/lib/python3.11/site-packages/sqlalchemy/engine/base.py:1808, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1806     conn = self._dbapi_connection
#    1807     if conn is None:
# -> 1808         conn = self._revalidate_connection()
#    1810     context = constructor(
#    1811         dialect, self, conn, execution_options, *args, **kw
#    1812     )
#    1813 except (exc.PendingRollbackError, exc.ResourceClosedError):
#
# File /opt/homebrew/lib/python3.11/site-packages/sqlalchemy/engine/base.py:665, in Connection._revalidate_connection(self)
#     663 if self.__can_reconnect and self.invalidated:
#     664     if self._transaction is not None:
# --> 665         self._invalid_transaction()
#     666     self._dbapi_connection = self.engine.raw_connection()
#     667     return self._dbapi_connection
#
# File /opt/homebrew/lib/python3.11/site-packages/sqlalchemy/engine/base.py:655, in Connection._invalid_transaction(self)
#     654 def _invalid_transaction(self) -> NoReturn:
# --> 655     raise exc.PendingRollbackError(
#     656         "Can't reconnect until invalid %stransaction is rolled "
#     657         "back.  Please rollback() fully before proceeding"
#     658         % ("savepoint " if self._nested_transaction is not None else ""),
#     659         code="8s2b",
#     660     )
#
# PendingRollbackError: Can't reconnect until invalid transaction is rolled back.  Please rollback() fully before proceeding (Background on this error at: https://sqlalche.me/e/20/8s2b)

# %% [markdown]
# # Fantasy data instruction

# %% [markdown]
# # Free Agents
# Updated daily

# %%
dh.fty_get_free_agents(fty_con, db_con)
# Out:
# --------------------- ESPN;95537 fty.free_agents
# ESPN;95537 fty.free_agents has been updated
#
#
#
# --------------------- Yahoo;121793 fty.free_agents
# 2024-11-05 21:03:32.902 - ERROR - query.py - yfpy.query:543 - No data found when attempting extraction from fields: ['league', 'players']
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File /opt/homebrew/lib/python3.11/site-packages/urllib3/connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#
# File /opt/homebrew/lib/python3.11/site-packages/urllib3/connection.py:507, in HTTPConnection.getresponse(self)
#     506 # Get the response from http.client.HTTPConnection
# --> 507 httplib_response = super().getresponse()
#     509 try:
#
# File /opt/homebrew/Cellar/python@3.11/3.11.10/Frameworks/Python.framework/Versions/3.11/lib/python3.11/http/client.py:1395, in HTTPConnection.getresponse(self)
#    1394 try:
# -> 1395     response.begin()
#    1396 except ConnectionError:
#
# File /opt/homebrew/Cellar/python@3.11/3.11.10/Frameworks/Python.framework/Versions/3.11/lib/python3.11/http/client.py:325, in HTTPResponse.begin(self)
#     324 while True:
# --> 325     version, status, reason = self._read_status()
#     326     if status != CONTINUE:
#
# File /opt/homebrew/Cellar/python@3.11/3.11.10/Frameworks/Python.framework/Versions/3.11/lib/python3.11/http/client.py:286, in HTTPResponse._read_status(self)
#     285 def _read_status(self):
# --> 286     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     287     if len(line) > _MAXLINE:
#
# File /opt/homebrew/Cellar/python@3.11/3.11.10/Frameworks/Python.framework/Versions/3.11/lib/python3.11/socket.py:718, in SocketIO.readinto(self, b)
#     717 try:
# --> 718     return self._sock.recv_into(b)
#     719 except timeout:
#
# File /opt/homebrew/Cellar/python@3.11/3.11.10/Frameworks/Python.framework/Versions/3.11/lib/python3.11/ssl.py:1314, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1311         raise ValueError(
#    1312           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1313           self.__class__)
# -> 1314     return self.read(nbytes, buffer)
#    1315 else:
#
# File /opt/homebrew/Cellar/python@3.11/3.11.10/Frameworks/Python.framework/Versions/3.11/lib/python3.11/ssl.py:1166, in SSLSocket.read(self, len, buffer)
#    1165 if buffer is not None:
# -> 1166     return self._sslobj.read(len, buffer)
#    1167 else:
#
# TimeoutError: The read operation timed out
#
# The above exception was the direct cause of the following exception:
#
# ReadTimeoutError                          Traceback (most recent call last)
# File /opt/homebrew/lib/python3.11/site-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#
# File /opt/homebrew/lib/python3.11/site-packages/urllib3/connectionpool.py:843, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     841     new_e = ProtocolError("Connection aborted.", new_e)
# --> 843 retries = retries.increment(
#     844     method, url, error=new_e, _pool=self, _stacktrace=sys.exc_info()[2]
#     845 )
#     846 retries.sleep()
#
# File /opt/homebrew/lib/python3.11/site-packages/urllib3/util/retry.py:474, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     473 if read is False or method is None or not self._is_method_retryable(method):
# --> 474     raise reraise(type(error), error, _stacktrace)
#     475 elif read is not None:
#
# File /opt/homebrew/lib/python3.11/site-packages/urllib3/util/util.py:39, in reraise(tp, value, tb)
#      38         raise value.with_traceback(tb)
# ---> 39     raise value
#      40 finally:
#
# File /opt/homebrew/lib/python3.11/site-packages/urllib3/connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#
# File /opt/homebrew/lib/python3.11/site-packages/urllib3/connectionpool.py:538, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     537 except (BaseSSLError, OSError) as e:
# --> 538     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#     539     raise
#
# File /opt/homebrew/lib/python3.11/site-packages/urllib3/connectionpool.py:369, in HTTPConnectionPool._raise_timeout(self, err, url, timeout_value)
#     368 if isinstance(err, SocketTimeout):
# --> 369     raise ReadTimeoutError(
#     370         self, url, f"Read timed out. (read timeout={timeout_value})"
#     371     ) from err
#     373 # See the above comment about EAGAIN in Python 3.
#
# ReadTimeoutError: HTTPSConnectionPool(host='fantasysports.yahooapis.com', port=443): Read timed out. (read timeout=300.0)
#
# During handling of the above exception, another exception occurred:
#
# ReadTimeout                               Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 dh.fty_get_free_agents(fty_con, db_con)
#
# File ~/git/nba_cockroach_db/dataHub.py:460, in dataHub.fty_get_free_agents(self, fty_con, db_con)
#     458     df = self._espn_get_free_agents(fty_con[con])
#     459 elif con.startswith('Yahoo'):
# --> 460     df = self._yahoo_get_free_agents(fty_con[con])
#     462 # Delete from database
#     463 db_ex = db_con.connect()
#
# File ~/git/nba_cockroach_db/dataHub.py:493, in dataHub._yahoo_get_free_agents(self, fty_con)
#     491 df = []
#     492 for player in fty_con.get_league_players():
# --> 493     p_ownership = fty_con.get_player_ownership(player.player_key)
#     494     if p_ownership.ownership.ownership_type in ['freeagents', 'waivers']:
#     495         df.append({
#     496             'season': Season.current_season,
#     497             'platform': 'Yahoo',
#    (...)
#     504             'player_position': p_ownership.display_position
#     505         })
#
# File /opt/homebrew/lib/python3.11/site-packages/yfpy/query.py:3070, in YahooFantasySportsQuery.get_player_ownership(self, player_key)
#    2979 def get_player_ownership(self, player_key: str) -> Player:
#    2980     """Retrieve ownership of specific player by player_key for chosen league.
#    2981
#    2982     Args:
#    (...)
#    3068
#    3069     """
# -> 3070     return self.query(
#    3071         f"https://fantasysports.yahooapis.com/fantasy/v2/league/{self.get_league_key()}/players;"
#    3072         f"player_keys={player_key}/ownership",
#    3073         ["league", "players", "0", "player"],
#    3074         Player
#    3075     )
#
# File /opt/homebrew/lib/python3.11/site-packages/yfpy/query.py:514, in YahooFantasySportsQuery.query(self, url, data_key_list, data_type_class, sort_function)
#     495 """Base query class to retrieve requested data from the Yahoo fantasy sports REST API.
#     496
#     497 Args:
#    (...)
#     511
#     512 """
#     513 if not self.offline:
# --> 514     response = self.get_response(url)
#     515     raw_response_data = response.json().get(self._fantasy_content_data_field)
#     517     # print(json.dumps(raw_response_data, indent=2))
#     518
#     519     # iterate through list of data keys and drill down to final desired data field
#
# File /opt/homebrew/lib/python3.11/site-packages/yfpy/query.py:432, in YahooFantasySportsQuery.get_response(self, url)
#     422 """Retrieve Yahoo Fantasy Sports data from the REST API.
#     423
#     424 Args:
#    (...)
#     429
#     430 """
#     431 logger.debug(f"Making request to URL: {url}")
# --> 432 response: Response = self.oauth.session.get(url, params={"format": "json"})
#     434 status_code = response.status_code
#     435 # when you exceed Yahoo's allowed data request limits, they throw a request status code of 999
#
# File /opt/homebrew/lib/python3.11/site-packages/requests/sessions.py:602, in Session.get(self, url, **kwargs)
#     594 r"""Sends a GET request. Returns :class:`Response` object.
#     595
#     596 :param url: URL for the new :class:`Request` object.
#     597 :param \*\*kwargs: Optional arguments that ``request`` takes.
#     598 :rtype: requests.Response
#     599 """
#     601 kwargs.setdefault("allow_redirects", True)
# --> 602 return self.request("GET", url, **kwargs)
#
# File /opt/homebrew/lib/python3.11/site-packages/rauth/session.py:358, in OAuth2Session.request(self, method, url, bearer_auth, **req_kwargs)
#     353     req_kwargs['params'].update({self.access_token_key:
#     354                                  self.access_token})
#     356 req_kwargs.setdefault('timeout', OAUTH2_DEFAULT_TIMEOUT)
# --> 358 return super(OAuth2Session, self).request(method, url, **req_kwargs)
#
# File /opt/homebrew/lib/python3.11/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File /opt/homebrew/lib/python3.11/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File /opt/homebrew/lib/python3.11/site-packages/requests/adapters.py:713, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     711     raise SSLError(e, request=request)
#     712 elif isinstance(e, ReadTimeoutError):
# --> 713     raise ReadTimeout(e, request=request)
#     714 elif isinstance(e, _InvalidHeader):
#     715     raise InvalidHeader(e, request=request)
#
# ReadTimeout: HTTPSConnectionPool(host='fantasysports.yahooapis.com', port=443): Read timed out. (read timeout=300.0)

# %% [markdown]
# # Fantasy Team Rosters
# Updated daily

# %%
dh.fty_get_competitor_roster(fty_con, db_con)
# Out:
# --------------------- ESPN;95537 fty.competitor_roster
# ESPN;95537 fty.competitor_roster has been updated
#
#
#
# --------------------- Yahoo;121793 fty.competitor_roster
# Yahoo;121793 fty.competitor_roster has been updated

# %% [markdown]
# # Fantasy Schedule

# %%
# dh.fty_get_league_schedule(fty_con, db_con)

# %% [markdown]
# # Fantasy Transactions

# %%
dh.fty_get_recent_activity(fty_con, db_con)
# Out:
# --------------------- ESPN;95537 fty.recent_activity
# ESPN;95537 fty.recent_activity has been updated
#
#
#
# --------------------- Yahoo;121793 fty.recent_activity
# Yahoo;121793 fty.recent_activity has been updated

# %% [markdown]
# # Fantasy Matchup Boxscores

# %%
# dh.fty_get_matchup_box_score(fty_con, db_con)
